# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
df = pd.read_excel('Concrete_Data.xls')
df
# Out:
#       Cement (component 1)(kg in a m^3 mixture)  \
# 0                                         540.0
# 1                                         540.0
# 2                                         332.5
# 3                                         332.5
# 4                                         198.6
# ...                                         ...
# 1025                                      276.4
# 1026                                      322.2
# 1027                                      148.5
# 1028                                      159.1
# 1029                                      260.9
#
#       Blast Furnace Slag (component 2)(kg in a m^3 mixture)  \
# 0                                                   0.0
# 1                                                   0.0
# 2                                                 142.5
# 3                                                 142.5
# 4                                                 132.4
# ...

# %%
df.shape
# Out:
# (1030, 9)

# %%
df.isna().sum()
# Out:
# Cement (component 1)(kg in a m^3 mixture)                0
# Blast Furnace Slag (component 2)(kg in a m^3 mixture)    0
# Fly Ash (component 3)(kg in a m^3 mixture)               0
# Water  (component 4)(kg in a m^3 mixture)                0
# Superplasticizer (component 5)(kg in a m^3 mixture)      0
# Coarse Aggregate  (component 6)(kg in a m^3 mixture)     0
# Fine Aggregate (component 7)(kg in a m^3 mixture)        0
# Age (day)                                                0
# Concrete compressive strength(MPa, megapascals)          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1030 entries, 0 to 1029
# Data columns (total 9 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   Cement (component 1)(kg in a m^3 mixture)              1030 non-null   float64
#  1   Blast Furnace Slag (component 2)(kg in a m^3 mixture)  1030 non-null   float64
#  2   Fly Ash (component 3)(kg in a m^3 mixture)             1030 non-null   float64
#  3   Water  (component 4)(kg in a m^3 mixture)              1030 non-null   float64
#  4   Superplasticizer (component 5)(kg in a m^3 mixture)    1030 non-null   float64
#  5   Coarse Aggregate  (component 6)(kg in a m^3 mixture)   1030 non-null   float64
#  6   Fine Aggregate (component 7)(kg in a m^3 mixture)      1030 non-null   float64
#  7   Age (day)                                              1030 non-null   int64
# ...

# %%
df.describe()
# Out:
#        Cement (component 1)(kg in a m^3 mixture)  \
# count                                1030.000000
# mean                                  281.165631
# std                                   104.507142
# min                                   102.000000
# 25%                                   192.375000
# 50%                                   272.900000
# 75%                                   350.000000
# max                                   540.000000
#
#        Blast Furnace Slag (component 2)(kg in a m^3 mixture)  \
# count                                        1030.000000
# mean                                           73.895485
# std                                            86.279104
# min                                             0.000000
# 25%                                             0.000000
# 50%                                            22.000000
# 75%                                           142.950000
# ...

# %%
fig = plt.figure(figsize = (10, 7))
plt.boxplot(df['Age (day)'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fe7d2f16eb0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fe7d2f20490>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fe7d2f16be0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fe7d2f20910>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fe7d2f20be0>],
#  'means': []}

# %%
def find_boundary(data, variables):
    Q1 = data[variables].quantile(.25)
    Q3 = data[variables].quantile(.75)
    IQR = Q3 - Q1
    lower_boundary = Q1 - 1.5*IQR
    upper_boundary = Q3 + 1.5*IQR
    
    return lower_boundary, upper_boundary

# %%
lower_fixed, upper_fixed = find_boundary(df, 'Blast Furnace Slag (component 2)(kg in a m^3 mixture)')
print("upper_fixed for Blast_Furnace is: ", upper_fixed)
print("lower_fixed for Blast_Furnace is: ", lower_fixed)
# Out:
# upper_fixed for Blast_Furnace is:  357.375
# lower_fixed for Blast_Furnace is:  -214.42499999999998

# %%
df['Blast Furnace Slag (component 2)(kg in a m^3 mixture)'] = np.where(df['Blast Furnace Slag (component 2)(kg in a m^3 mixture)']>upper_fixed, upper_fixed, 
                                np.where(df['Blast Furnace Slag (component 2)(kg in a m^3 mixture)']<lower_fixed, lower_fixed, df['Blast Furnace Slag (component 2)(kg in a m^3 mixture)']))

# %%
lower_fixed, upper_fixed = find_boundary(df, 'Water  (component 4)(kg in a m^3 mixture)')
print("upper_fixed for Water is: ", upper_fixed)
print("lower_fixed for Water is: ", lower_fixed)
# Out:
# upper_fixed for Water is:  232.64999999999998
# lower_fixed for Water is:  124.25000000000001

# %%
df['Water  (component 4)(kg in a m^3 mixture)'] = np.where(df['Water  (component 4)(kg in a m^3 mixture)']>upper_fixed, upper_fixed, 
                                np.where(df['Water  (component 4)(kg in a m^3 mixture)']<lower_fixed, lower_fixed, df['Water  (component 4)(kg in a m^3 mixture)']))

# %%
lower_fixed, upper_fixed = find_boundary(df, 'Superplasticizer (component 5)(kg in a m^3 mixture)')
print("upper_fixed for Superplasticizer is: ", upper_fixed)
print("lower_fixed for Superplasticizer is: ", lower_fixed)
# Out:
# upper_fixed for Superplasticizer is:  25.4
# lower_fixed for Superplasticizer is:  -15.24

# %%
df['Superplasticizer (component 5)(kg in a m^3 mixture)'] = np.where(df['Superplasticizer (component 5)(kg in a m^3 mixture)']>upper_fixed, upper_fixed, 
                                np.where(df['Superplasticizer (component 5)(kg in a m^3 mixture)']<lower_fixed, lower_fixed, df['Superplasticizer (component 5)(kg in a m^3 mixture)']))

# %%
lower_fixed, upper_fixed = find_boundary(df, 'Fine Aggregate (component 7)(kg in a m^3 mixture)')
print("upper_fixed for Fine_Aggregate is: ", upper_fixed)
print("lower_fixed for Fine_Aggregate is: ", lower_fixed)
# Out:
# upper_fixed for Fine_Aggregate is:  963.5749999999999
# lower_fixed for Fine_Aggregate is:  591.3750000000001

# %%
df['Fine Aggregate (component 7)(kg in a m^3 mixture)'] = np.where(df['Fine Aggregate (component 7)(kg in a m^3 mixture)']>upper_fixed, upper_fixed, 
                                np.where(df['Fine Aggregate (component 7)(kg in a m^3 mixture)']<lower_fixed, lower_fixed, df['Fine Aggregate (component 7)(kg in a m^3 mixture)']))

# %%
lower_fixed, upper_fixed = find_boundary(df, 'Age (day)')
print("upper_fixed for Age is: ", upper_fixed)
print("lower_fixed for Age is: ", lower_fixed)
# Out:
# upper_fixed for Age is:  129.5
# lower_fixed for Age is:  -66.5

# %%
df['Age (day)'] = np.where(df['Age (day)']>upper_fixed, upper_fixed, 
                                np.where(df['Age (day)']<lower_fixed, lower_fixed, df['Age (day)']))

# %%
fig = plt.figure(figsize = (10, 7))
plt.boxplot(df['Concrete compressive strength(MPa, megapascals) '])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fe7d2ed55e0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fe7d2ed5b80>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fe7d2ed5310>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fe7d2ede160>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fe7d2ede430>],
#  'means': []}

# %%
df.shape
# Out:
# (1030, 9)

# %%
df.describe()
# Out:
#        Cement (component 1)(kg in a m^3 mixture)  \
# count                                1030.000000
# mean                                  281.165631
# std                                   104.507142
# min                                   102.000000
# 25%                                   192.375000
# 50%                                   272.900000
# 75%                                   350.000000
# max                                   540.000000
#
#        Blast Furnace Slag (component 2)(kg in a m^3 mixture)  \
# count                                        1030.000000
# mean                                           73.891553
# std                                            86.266125
# min                                             0.000000
# 25%                                             0.000000
# 50%                                            22.000000
# 75%                                           142.950000
# ...

# %% [markdown]
# # seaborn correlation heatmap

# %%
plt.figure(figsize = (15, 10))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Seaborn Pairplot

# %%
sns.pairplot(df, height=2.0)

# %%
X = df.drop(columns=['Concrete compressive strength(MPa, megapascals) ', 'Coarse Aggregate  (component 6)(kg in a m^3 mixture)'])
y = df['Concrete compressive strength(MPa, megapascals) ']

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
def calcu_mult(df):
    vif = pd.DataFrame()
    vif["variables"] = X.columns
    vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

    return vif

# %%
calcu_mult(X)
# Out:
#                                            variables        VIF
# 0          Cement (component 1)(kg in a m^3 mixture)  14.635882
# 1  Blast Furnace Slag (component 2)(kg in a m^3 m...   3.346541
# 2         Fly Ash (component 3)(kg in a m^3 mixture)   4.094700
# 3          Water  (component 4)(kg in a m^3 mixture)  72.283423
# 4  Superplasticizer (component 5)(kg in a m^3 mix...   5.727859
# 5  Fine Aggregate (component 7)(kg in a m^3 mixture)  48.739836
# 6                                          Age (day)   2.248100

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
from sklearn.preprocessing import MinMaxScaler, PolynomialFeatures

# %%
scale = MinMaxScaler()
X_train_Min = pd.DataFrame(scale.fit_transform(X_train))

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
regr = RandomForestRegressor(random_state=5, max_depth=4)
regr.fit(X_train_val, y_train_val)
# Out:
# RandomForestRegressor(max_depth=4, random_state=5)

# %%
features = X_train_val.columns
importances = regr.feature_importances_
indices = np.argsort(importances)[-8:]
plt.title('Feature Importances')
plt.barh(range(len(indices)), importances[indices], color='blue', align='center')
plt.yticks(range(len(indices)), [features[i] for i in indices])
plt.xlabel('Relative Importance')
plt.show()

# %%
model = Ridge()
linReg = model.fit(X_train, y_train)

# %%
linRig_coef = linReg.score(X_train, y_train)
linRig_coef
# Out:
# 0.7426691651995103

# %%
#Adjusted R2
1 - (1-linRig.score(X_train, y_train))*(len(y_train)-1)/(len(y_train)-X_train.shape[1]-1)
# Out:
# 0.7366168686078816

# %%
intercept = model.coef_
intercept
# Out:
# array([ 0.11120455,  0.09165106,  0.069556  , -0.2021602 ,  0.28879878,
#         0.00085815,  0.25555668])

# %%
y_predict = linRig.predict(X_test)

# %%
print("MAE : ",mean_absolute_error(y_test, y_predict))
print("MSE : ",mean_squared_error(y_test, y_predict))
print("R2 score : ",r2_score(y_test, y_predict))
# Out:
# MAE :  7.359341572518357
# MSE :  87.6333387450168
# R2 score :  0.6638488997914304

# %%
model = Ridge()
visualizer = ResidualsPlot(model, hist=True, qqplot=False)

visualizer.fit(X_train, y_train)  
visualizer.score(X_test, y_test)  
visualizer.show()
# Out:
# <AxesSubplot:title={'center':'Residuals for Ridge Model'}, xlabel='Predicted Value', ylabel='Residuals'>
